# %% [markdown]
# # Welcome to Project-3-python
#
# This is a starter Jupyter notebook to help you get started with this Python project.
#
# ## What is this notebook?
#
# This notebook serves as an interactive introduction to the project. You can run code cells, experiment with Python code, and explore the project's functionality.

# %% [markdown]
# ## Getting Started
#
# Before you begin, make sure you have:
# - Python 3.x installed
# - Jupyter Notebook or JupyterLab installed
#
# You can install Jupyter using pip:
# ```bash
# pip install jupyter
# ```
#
# To run this notebook:
# ```bash
# jupyter notebook starter.ipynb
# ```

# %% [markdown]
# ## Basic Python Examples
#
# Let's start with some basic Python code to make sure everything is working correctly.

# %%
# Hello World
print("Hello, World!")
print("Welcome to Project-3-python")

# %%
# Basic arithmetic operations
a = 10
b = 5

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")

# %% [markdown]
# ## Working with Lists
#
# Python lists are versatile data structures. Here are some common operations:

# %%
# Creating and manipulating lists
numbers = [1, 2, 3, 4, 5]
print("Original list:", numbers)

# Adding elements
numbers.append(6)
print("After append:", numbers)

# List comprehension
squares = [x**2 for x in numbers]
print("Squares:", squares)

# %% [markdown]
# ## Working with Functions
#
# Functions help organize and reuse code:

# %%
def greet(name):
    """
    A simple greeting function
    
    Args:
        name (str): The name to greet
    
    Returns:
        str: A greeting message
    """
    return f"Hello, {name}! Welcome to Python programming."

# Test the function
message = greet("Developer")
print(message)

# %% [markdown]
# ## Data Analysis Preview
#
# If you have pandas installed, you can work with data:

# %%
# Uncomment the following lines if you have pandas installed
# import pandas as pd
# 
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#     'Age': [25, 30, 35, 28],
#     'Score': [85, 90, 78, 92]
# }
# 
# df = pd.DataFrame(data)
# print(df)
# print("\nSummary statistics:")
# print(df.describe())

print("Install pandas with: pip install pandas")

# %% [markdown]
# ## Next Steps
#
# Now that you've explored the basics, you can:
#
# 1. **Experiment**: Modify the code cells above and see what happens
# 2. **Add new cells**: Use the `+` button in the toolbar to add new cells
# 3. **Learn more**: Check out the [Python documentation](https://docs.python.org/3/)
# 4. **Explore Jupyter**: Learn about [Jupyter Notebook features](https://jupyter-notebook.readthedocs.io/)
#
# Happy coding!

# %% [markdown]
# ## Resources
#
# - [Python Official Documentation](https://docs.python.org/3/)
# - [Jupyter Notebook Documentation](https://jupyter-notebook.readthedocs.io/)
# - [Python Tutorial](https://docs.python.org/3/tutorial/)
# - [Real Python Tutorials](https://realpython.com/)
